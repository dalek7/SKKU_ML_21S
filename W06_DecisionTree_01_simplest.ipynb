# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# %%
X = [[0, 0], [1, 1]]
Y = [0, 1]

# %%
X = np.array(X)
Y = np.array(Y)

# %%
x1 = X[:, 0]
x2 = X[:, 1]

# %%
#plt.figure(dpi=150)
plt.scatter(x1, x2, c=Y)
plt.grid('on')
plt.axis('equal')
# Out:
# (-0.05985663082437276,
#  1.0598566308243726,
#  -0.06517660044150109,
#  1.065176600441501)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, Y)

# %%
clf.predict([[2., 2.]])
# Out:
# array([1])

# %%
from sklearn.tree import export_graphviz
import pydotplus
from IPython.display import Image

dot_data = export_graphviz(clf, out_file=None, feature_names=['x0', 'x1'],
                           filled=True, rounded=True, special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())
